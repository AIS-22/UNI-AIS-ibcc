# %%
import numpy as np
import matplotlib.pyplot as plt

# open npy file
temp = np.load("data/03001627_inputRGB/1a6f615e8b1b5ae4dbbc9440457e303e.npy")
#plt.imshow(temp[2])
# subplot of 24 images
fig, axs = plt.subplots(4, 6, figsize=(10, 10))
for i in range(4):
    for j in range(6):
        axs[i, j].imshow(temp[i*6+j])
plt.show()

# %%
# %matplotlib widget
import scipy.io as sio
# open npy file
temp = np.load("data/03001627_inputRGB/1a6f615e8b1b5ae4dbbc9440457e303e.npy")
#plt.imshow(temp[2])
# subplot of 24 images
#fig, axs = plt.subplots(4, 6, figsize=(10, 10))
#for i in range(4):
#    for j in range(6):
#        axs[i, j].imshow(temp[i*6+j])
#plt.show()
imageNr = 3
# open mat file
temp = sio.loadmat("results/ORIG_STG2_sgd_trueWD_restart_cont1/f439a2db6341cd85f2b931201029bc76.mat")
#print(temp)
plt.imshow(temp['image'][imageNr])
plt.show()
# plot 3d points
fig = plt.figure()
#print(temp['pointcloud'][0][0])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(temp['pointcloud'][imageNr][0][:,0], temp['pointcloud'][imageNr][0][:,1], temp['pointcloud'][imageNr][0][:,2])
plt.show()
#temp = sio.loadmat("data/03001627_depth_fixed8/2cbbe7f1f1f75e34d28b52ade6c7e48.mat")
##print(temp1)
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter(temp['Z'][0], temp['Z'][1], temp['Z'][2])
#plt.show()
#temp = sio.loadmat("data/03001627_depth/2cbbe7f1f1f75e34d28b52ade6c7e48.mat")
##print(temp1)
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter(temp['Z'][0], temp['Z'][1], temp['Z'][2])
#plt.show()
#temp = sio.loadmat("data/03001627_testGT/2cbbe7f1f1f75e34d28b52ade6c7e48.mat")
##print(temp['V'][:])
#fig = plt.figure()
#ax = fig.add_subplot(111, projection='3d')
#ax.scatter(temp['Vd'][:,0], temp['Vd'][:,1], temp['Vd'][:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
